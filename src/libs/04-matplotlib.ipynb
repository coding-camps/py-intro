# %% [markdown]
# # Matplot

# %% [markdown]
# - 官网：
# - 参考 matplotlib：https://zhuanlan.zhihu.com/p/342422162

# %%
import matplotlib
from matplotlib import font_manager as fm

# Matplotlib加载的配置文件
print(matplotlib.matplotlib_fname())
# 打印本地中的所有字体
for idx, font in enumerate(fm.fontManager.ttflist):
    print(f'{idx}: {font.name}', end='\n' if (idx + 1) % 5 == 0 else '    ')
# Out:
# /Users/cosmos/WorkSpace/_configs/py-envs/py312-all/lib/python3.12/site-packages/matplotlib/mpl-data/matplotlibrc
# 0: STIXSizeFourSym    1: STIXSizeFiveSym    2: DejaVu Sans Display    3: DejaVu Serif    4: STIXGeneral
# 5: DejaVu Sans    6: cmss10    7: STIXNonUnicode    8: DejaVu Sans Mono    9: STIXSizeOneSym
# 10: STIXNonUnicode    11: STIXGeneral    12: DejaVu Sans Mono    13: STIXSizeFourSym    14: STIXGeneral
# 15: DejaVu Serif    16: STIXSizeOneSym    17: DejaVu Sans    18: DejaVu Serif    19: cmex10
# 20: DejaVu Sans    21: DejaVu Serif Display    22: cmb10    23: STIXSizeThreeSym    24: STIXNonUnicode
# 25: STIXNonUnicode    26: STIXSizeThreeSym    27: DejaVu Serif    28: STIXSizeTwoSym    29: cmtt10
# 30: cmsy10    31: DejaVu Sans Mono    32: cmr10    33: STIXGeneral    34: DejaVu Sans
# 35: DejaVu Sans Mono    36: cmmi10    37: STIXSizeTwoSym    38: Noto Sans Thaana    39: Noto Sans Miao
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

myfont = {
    "mathtext.fontset": 'stix',
    'font.family': 'Songti SC',
    'font.sans-serif': 'Songti SC',
    'axes.unicode_minus': False
}
plt.rcParams.update(myfont)

if __name__ == '__main__':
    x = np.linspace(-8, 8, 1024)
    y1 = 0.618 * np.abs(x) - 0.8 * np.sqrt(64 - x ** 2)
    y2 = 0.618 * np.abs(x) + 0.8 * np.sqrt(64 - x ** 2)
    plt.plot(x, y1, color='r')
    plt.plot(x, y2, color='r')
    plt.title("爱Love", fontsize=20, color="b")
    plt.show()
